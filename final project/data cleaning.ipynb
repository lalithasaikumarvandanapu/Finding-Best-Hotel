# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ### Load the dataset

# %%
df = pd.read_excel(r"D:\INNOMATICS\DATA ANALYTICS\01-Python\final project\files\final_df.xlsx")

# %% [markdown]
# ### Inspect the dataset

# %%
df.shape # check the shape of the datatset
# Out:
# (503, 10)

# %%
df.head()  # Check top 5 observations
# Out:
#                                         Hotel   Location  Ratings
# 0                                Hotel Campal     Panjim      3.8  \
# 1  ibis Styles Goa Calangute - An Accor Brand  Calangute      4.1
# 2                                  SinQ Prive   Candolim      4.0
# 3                          Ginger Goa, Panjim     Panjim      3.9
# 5     The Yellow House, Goa - IHCL SeleQtions     Anjuna      4.2
#
#    No_of_Ratings  Original_price Discount_price  Taxes Building_Type
# 0           1164            2549           2042    528     Apartment  \
# 1           4348            5750              0    690     Apartment
# 2           2251            3690           3010    720     Apartment
# 3           5840            5149              0    618     Apartment
# 5             71            7499              0    900        Resort
#
#                   House_Rule hotel_type
# 0            Alcohol Allowed     3 star
# 1  Unmarried Couples Allowed     4 star
# ...

# %%
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df.head(30)
# Out:
#                                                 Hotel             Location
# 0                                        Hotel Campal               Panjim  \
# 1          ibis Styles Goa Calangute - An Accor Brand            Calangute
# 2                                          SinQ Prive             Candolim
# 3                                  Ginger Goa, Panjim               Panjim
# 4   Calangute Heights by Stay ALYF | Luxury 1 BHK ...            Calangute
# 5             The Yellow House, Goa - IHCL SeleQtions               Anjuna
# 6                     I Love Bell Bottoms Vagator Goa              Vagator
# 7                                  Novotel Goa Panjim               Panjim
# 8                                 Goa Woodlands Hotel               Margao
# 9                                                Half            Calangute
# 10                                  Hotel Jyoti Plaza               Margao
# ...

# %%
df.info() # Check the dataset information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           880 non-null    object
#  1   Location        880 non-null    object
#  2   Ratings         849 non-null    float64
#  3   No_of_Ratings   864 non-null    float64
#  4   No_of_Reviews   714 non-null    float64
#  5   Original_price  880 non-null    object
#  6   Discount_price  743 non-null    object
#  7   Taxes           877 non-null    object
#  8   Building_Type   572 non-null    object
#  9   House_Rule      732 non-null    object
#  10  hotel_type      553 non-null    object
# dtypes: float64(3), object(8)
# memory usage: 75.8+ KB

# %%
df.dtypes
df.dtypes.value_counts()
# Out:
# Hotel              object
# Location           object
# Ratings           float64
# No_of_Ratings       int32
# Original_price      int32
# Discount_price     object
# Taxes               int32
# Building_Type      object
# House_Rule         object
# hotel_type         object
# dtype: object
# object     6
# int32      3
# float64    1
# Name: count, dtype: int64

# %% [markdown]
# __drop unnecessary columns__

# %%
df.drop('No_of_Reviews', axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Hotel               0
# Location            0
# Ratings            31
# No_of_Ratings      16
# Original_price      0
# Discount_price    137
# Taxes               3
# Building_Type     308
# House_Rule        148
# hotel_type        327
# dtype: int64

# %% [markdown]
# __drop rows that have null values__

# %%
df.dropna(subset=['Building_Type'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 572 entries, 0 to 879
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           572 non-null    object
#  1   Location        572 non-null    object
#  2   Ratings         550 non-null    float64
#  3   No_of_Ratings   563 non-null    float64
#  4   Original_price  572 non-null    object
#  5   Discount_price  478 non-null    object
#  6   Taxes           569 non-null    object
#  7   Building_Type   572 non-null    object
#  8   House_Rule      526 non-null    object
#  9   hotel_type      429 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 49.2+ KB

# %%
df.dropna(subset=['House_Rule'], inplace = True)

# %%
df.isna().sum()
# Out:
# Hotel               0
# Location            0
# Ratings            20
# No_of_Ratings       7
# Original_price      0
# Discount_price     89
# Taxes               3
# Building_Type       0
# House_Rule          0
# hotel_type        120
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 526 entries, 0 to 878
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           526 non-null    object
#  1   Location        526 non-null    object
#  2   Ratings         506 non-null    float64
#  3   No_of_Ratings   519 non-null    float64
#  4   Original_price  526 non-null    object
#  5   Discount_price  437 non-null    object
#  6   Taxes           523 non-null    object
#  7   Building_Type   526 non-null    object
#  8   House_Rule      526 non-null    object
#  9   hotel_type      406 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 45.2+ KB

# %%
df['Ratings'].isna().sum()
# Out:
# 20

# %%
df[df['Ratings'].isna()]
# Out:
#                                              Hotel             Location
# 7                               Novotel Goa Panjim               Panjim  \
# 68           SaffronStays Magnolias by River Moira               Bardez
# 79                  Ocean View The Apartment Hotel             Mormugao
# 194                    Country Inn Panjim Goa, Goa               Panjim
# 279                       Palette Saligao Porvorim               Bardez
# 304     Olive Alidia Beach Resort by Embassy Group                 Baga
# 475                        Sea breeze Village Baga  Calangute Baga Road
# 500                      Tangerine Boutique Resort            Calangute
# 647                           Senhor Angelo Resort            Calangute
# 650                                  Rivasa Resort  Calangute Baga Road
# 698                HOTEL BHAGWATI BY PEARL HARBOUR                 Baga
# 708  Grandeur De Sanchi- Luxury Beach Resort & Spa            Calangute
# ...

# %%
df = df[~(df['Ratings'].isna() & df['No_of_Ratings'].notna())]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 513 entries, 0 to 878
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           513 non-null    object
#  1   Location        513 non-null    object
#  2   Ratings         506 non-null    float64
#  3   No_of_Ratings   506 non-null    float64
#  4   Original_price  513 non-null    object
#  5   Discount_price  424 non-null    object
#  6   Taxes           510 non-null    object
#  7   Building_Type   513 non-null    object
#  8   House_Rule      513 non-null    object
#  9   hotel_type      398 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 44.1+ KB

# %%
df[df['Ratings'].isna()]
# Out:
#                                           Hotel Location  Ratings
# 7                            Novotel Goa Panjim   Panjim      NaN  \
# 68        SaffronStays Magnolias by River Moira   Bardez      NaN
# 279                    Palette Saligao Porvorim   Bardez      NaN
# 304  Olive Alidia Beach Resort by Embassy Group     Baga      NaN
# 733                      Marron Sea View Resort  Palolem      NaN
# 764                                 Garden View   Arpora      NaN
# 841                           Eve Resort Patnem  Palolem      NaN
#
#      No_of_Ratings Original_price Discount_price  Taxes Building_Type
# 7              NaN          12,29            NaN  2,214     Apartment  \
# 68             NaN          35,63            NaN  5,887         Villa
# 279            NaN          4,523          1,191    253     Apartment
# 304            NaN          3,570          2,338    478        Resort
# 733            NaN          5,750          5,348  1,093        Resort
# ...

# %%
df[df['No_of_Ratings'].isna()]
# Out:
#                                           Hotel Location  Ratings
# 7                            Novotel Goa Panjim   Panjim      NaN  \
# 68        SaffronStays Magnolias by River Moira   Bardez      NaN
# 279                    Palette Saligao Porvorim   Bardez      NaN
# 304  Olive Alidia Beach Resort by Embassy Group     Baga      NaN
# 733                      Marron Sea View Resort  Palolem      NaN
# 764                                 Garden View   Arpora      NaN
# 841                           Eve Resort Patnem  Palolem      NaN
#
#      No_of_Ratings Original_price Discount_price  Taxes Building_Type
# 7              NaN          12,29            NaN  2,214     Apartment  \
# 68             NaN          35,63            NaN  5,887         Villa
# 279            NaN          4,523          1,191    253     Apartment
# 304            NaN          3,570          2,338    478        Resort
# 733            NaN          5,750          5,348  1,093        Resort
# ...

# %%
df.dropna(subset = ['Ratings', 'No_of_Ratings'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 506 entries, 0 to 878
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           506 non-null    object
#  1   Location        506 non-null    object
#  2   Ratings         506 non-null    float64
#  3   No_of_Ratings   506 non-null    float64
#  4   Original_price  506 non-null    object
#  5   Discount_price  419 non-null    object
#  6   Taxes           503 non-null    object
#  7   Building_Type   506 non-null    object
#  8   House_Rule      506 non-null    object
#  9   hotel_type      395 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 43.5+ KB

# %%
df.dropna(subset = ['Taxes'], inplace = True)

# %%
df.head(100)
# Out:
#                                               Hotel           Location
# 0                                      Hotel Campal             Panjim  \
# 1        ibis Styles Goa Calangute - An Accor Brand          Calangute
# 2                                        SinQ Prive           Candolim
# 3                                Ginger Goa, Panjim             Panjim
# 5           The Yellow House, Goa - IHCL SeleQtions             Anjuna
# ..                                              ...                ...
# 158                           Bogmallo Beach Resort      Bogmalo Beach
# 161                                   The Crown Goa  31st January Road
# 165               Heritage Village Resort & Spa Goa      Arossim Beach
# 168                                      Tan N Sand       Ashwem Beach
# 169  Estrela Do Mar Beach Resort - A Beach Property          Calangute
#
#      Ratings  No_of_Ratings Original_price Discount_price  Taxes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, 0 to 878
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           503 non-null    object
#  1   Location        503 non-null    object
#  2   Ratings         503 non-null    float64
#  3   No_of_Ratings   503 non-null    float64
#  4   Original_price  503 non-null    object
#  5   Discount_price  419 non-null    object
#  6   Taxes           503 non-null    object
#  7   Building_Type   503 non-null    object
#  8   House_Rule      503 non-null    object
#  9   hotel_type      394 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 43.2+ KB

# %%
#clean original, discount, taxes prices

# %%
df['Original_price'] = df['Original_price'].replace({'₹': '', ',': ''}, regex=True).astype(int)

# %%
df['Original_price'].dtype
# Out:
# dtype('int32')

# %%
df.head()
# Out:
#                                         Hotel   Location  Ratings
# 0                                Hotel Campal     Panjim      3.8  \
# 1  ibis Styles Goa Calangute - An Accor Brand  Calangute      4.1
# 2                                  SinQ Prive   Candolim      4.0
# 3                          Ginger Goa, Panjim     Panjim      3.9
# 5     The Yellow House, Goa - IHCL SeleQtions     Anjuna      4.2
#
#    No_of_Ratings  Original_price Discount_price Taxes Building_Type
# 0         1164.0            2549          2,042   528     Apartment  \
# 1         4348.0            5750            NaN   690     Apartment
# 2         2251.0            3690          3,010   720     Apartment
# 3         5840.0            5149            NaN   618     Apartment
# 5           71.0            7499            NaN   900        Resort
#
#                   House_Rule hotel_type
# 0            Alcohol Allowed        NaN
# 1  Unmarried Couples Allowed     4 star
# ...

# %%
df['No_of_Ratings'] = df['No_of_Ratings'].astype(int)

# %%
df.Discount_price.fillna(0,inplace = True)

# %%
print(df['Discount_price'].value_counts().head(100))
# Out:
# Discount_price
# 0         84
#  3,349     3
#  2,164     3
#  2,048     3
#  2,458     3
#           ..
#  1,714     1
#  6,983     1
#  1,040     1
#  2,121     1
#  599+      1
# Name: count, Length: 100, dtype: int64

# %%
df['Discount_price'] = df['Discount_price'].str.replace('+','')
df['Discount_price'] = df['Discount_price'].str.replace(' t','')
df['Discount_price'] = df['Discount_price'].str.replace(',','')

# %%
df.Discount_price.fillna('0', inplace = True)

# %%
df.Discount_price.astype(int)
# Out:
# 0      2042
# 1         0
# 2      3010
# 3         0
# 5         0
#        ...
# 869    4772
# 872       0
# 874       0
# 877     911
# 878       0
# Name: Discount_price, Length: 503, dtype: int32

# %%
df['Discount_price'].value_counts()
# Out:
# Discount_price
# 0        84
#  3349     3
#  2164     3
#  2048     3
#  2458     3
#          ..
#  2587     1
#  3204     1
#  3004     1
#  2009     1
#  911      1
# Name: count, Length: 384, dtype: int64

# %% [markdown]
# project data cleaning:

# %%
df['Taxes'] = df['Taxes'].str.replace('+','')
df['Taxes'] = df['Taxes'].str.replace(',','')

# %%
df['Taxes'] = df['Taxes'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, 0 to 878
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           503 non-null    object
#  1   Location        503 non-null    object
#  2   Ratings         503 non-null    float64
#  3   No_of_Ratings   503 non-null    int32
#  4   Original_price  503 non-null    int32
#  5   Discount_price  503 non-null    object
#  6   Taxes           503 non-null    int32
#  7   Building_Type   503 non-null    object
#  8   House_Rule      503 non-null    object
#  9   hotel_type      394 non-null    object
# dtypes: float64(1), int32(3), object(6)
# memory usage: 37.3+ KB

# %%
df
# Out:
#                                           Hotel   Location  Ratings
# 0                                  Hotel Campal     Panjim      3.8  \
# 1    ibis Styles Goa Calangute - An Accor Brand  Calangute      4.1
# 2                                    SinQ Prive   Candolim      4.0
# 3                            Ginger Goa, Panjim     Panjim      3.9
# 5       The Yellow House, Goa - IHCL SeleQtions     Anjuna      4.2
# ..                                          ...        ...      ...
# 869                        Aarju Luxurious Wave  Calangute      4.1
# 872       The Postcard Hideaway, Netravali, Goa  South Goa      4.9
# 874     V are Family | Three Solace 3 BHK Villa   Candolim      4.4
# 877                         Subhash Guest House       Baga      3.4
# 878                    Villa Calangute Phase 12  Calangute      4.4
#
#      No_of_Ratings  Original_price Discount_price  Taxes Building_Type
# 0             1164            2549           2042    528     Apartment  \
# ...

# %%
df.hotel_type.value_counts(dropna = False)
# Out:
# hotel_type
# 3 star    238
# 4 star    110
# NaN       109
# 5 star     46
# Name: count, dtype: int64

# %%
df['hotel_type'].fillna(df['hotel_type'].mode()[0], inplace = True)

# %%
df.hotel_type.value_counts()
# Out:
# hotel_type
# 3 star    347
# 4 star    110
# 5 star     46
# Name: count, dtype: int64

# %%
df
# Out:
#                                           Hotel   Location  Ratings
# 0                                  Hotel Campal     Panjim      3.8  \
# 1    ibis Styles Goa Calangute - An Accor Brand  Calangute      4.1
# 2                                    SinQ Prive   Candolim      4.0
# 3                            Ginger Goa, Panjim     Panjim      3.9
# 5       The Yellow House, Goa - IHCL SeleQtions     Anjuna      4.2
# ..                                          ...        ...      ...
# 869                        Aarju Luxurious Wave  Calangute      4.1
# 872       The Postcard Hideaway, Netravali, Goa  South Goa      4.9
# 874     V are Family | Three Solace 3 BHK Villa   Candolim      4.4
# 877                         Subhash Guest House       Baga      3.4
# 878                    Villa Calangute Phase 12  Calangute      4.4
#
#      No_of_Ratings  Original_price Discount_price  Taxes Building_Type
# 0             1164            2549           2042    528     Apartment  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, 0 to 878
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hotel           503 non-null    object
#  1   Location        503 non-null    object
#  2   Ratings         503 non-null    float64
#  3   No_of_Ratings   503 non-null    int32
#  4   Original_price  503 non-null    int32
#  5   Discount_price  503 non-null    object
#  6   Taxes           503 non-null    int32
#  7   Building_Type   503 non-null    object
#  8   House_Rule      503 non-null    object
#  9   hotel_type      503 non-null    object
# dtypes: float64(1), int32(3), object(6)
# memory usage: 37.3+ KB
